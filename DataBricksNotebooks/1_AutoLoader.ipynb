# %%
# %sql
CREATE SCHEMA netflix_catalog.net_schema
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
chkpoint = "abfss://silver@netflixstoragetunir.dfs.core.windows.net/checkpoint"

# %%
df = spark.readStream.format("cloudfiles").option("cloudfiles.format","csv").option("cloudFiles.SchemaLocation","abfss://raw@netflixstoragetunir.dfs.core.windows.net/checkpoint").load("abfss://raw@netflixstoragetunir.dfs.core.windows.net/")

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.writeStream \
    .option("checkpointLocation", "abfss://silver@netflixstoragetunir.dfs.core.windows.net/checkpoint") \
    .outputMode("append") \
    .trigger(processingTime="10 seconds") \
    .start("abfss://bronze@netflixstoragetunir.dfs.core.windows.net/netflix_titles")
# Out:
# Out[25]: <pyspark.sql.streaming.query.StreamingQuery at 0x79cb28372790>
